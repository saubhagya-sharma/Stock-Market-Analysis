# %% [markdown]
# <a href="https://colab.research.google.com/github/saubhagya-sharma/Stock-Market-Analysis/blob/main/Stock_Market_fbprophet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tesla (TSLA) Stock Price prediction using Facebook Prophet

# %% [markdown]
# ## Importing all the necessary Libraries

# %%
import pandas as pd
import plotly.express as px
from fbprophet import Prophet

# %%
 #Initializing Plotly
import plotly.io as pio
pio.renderers.default='colab'

# %% [markdown]
# ## Importing the Dataset & Exploring it

# %%
df=pd.read_csv('TSLA.csv')

# %%
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2020-03-16   93.900002   98.973999   88.433998   89.014000   89.014000
# 1    2020-03-17   88.001999   94.370003   79.199997   86.040001   86.040001
# 2    2020-03-18   77.800003   80.972000   70.101997   72.244003   72.244003
# 3    2020-03-19   74.940002   90.400002   71.692001   85.528000   85.528000
# 4    2020-03-20   87.639999   95.400002   85.157997   85.505997   85.505997
# ..          ...         ...         ...         ...         ...         ...
# 246  2021-03-08  600.549988  620.130005  558.789978  563.000000  563.000000
# 247  2021-03-09  608.179993  678.090027  595.210022  673.580017  673.580017
# 248  2021-03-10  700.299988  717.849976  655.059998  668.059998  668.059998
# 249  2021-03-11  699.400024  702.500000  677.179993  699.599976  699.599976
# 250  2021-03-12  670.000000  694.880005  666.140015  693.729980  693.729980
#
#         Volume
# 0    102447500
# 1    119973000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       251 non-null    object
#  1   Open       251 non-null    float64
#  2   High       251 non-null    float64
#  3   Low        251 non-null    float64
#  4   Close      251 non-null    float64
#  5   Adj Close  251 non-null    float64
#  6   Volume     251 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 13.9+ KB

# %%
df.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  251.000000  251.000000  251.000000  251.000000  251.000000
# mean   414.739109  425.323268  402.764717  415.137952  415.137952
# std    234.908560  239.374833  229.101662  234.987820  234.987820
# min     74.940002   80.972000   70.101997   72.244003   72.244003
# 25%    194.901001  199.384003  188.566994  193.368995  193.368995
# 50%    408.951996  418.700012  401.660004  408.500000  408.500000
# 75%    606.549988  627.795013  586.750000  607.234985  607.234985
# max    891.380005  900.400024  871.599976  883.090027  883.090027
#
#              Volume
# count  2.510000e+02
# mean   6.178552e+07
# std    3.306128e+07
# min    1.515770e+07
# 25%    3.628290e+07
# 50%    5.561600e+07
# 75%    8.131825e+07
# max    2.221262e+08

# %% [markdown]
# # Data Visualization using plotly express- Visualizing the historical performance of Tesla

# %%
px.area(df, x='Date', y='Close')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.line(df, x='Date', y='Close')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.area(df, x='Date', y='Volume')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.bar(df, y='Volume')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.box(df, y='Close')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Understanding Facebook Prophet

# %% [markdown]
# ## Data Preperation

# %%
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2020-03-16   93.900002   98.973999   88.433998   89.014000   89.014000
# 1    2020-03-17   88.001999   94.370003   79.199997   86.040001   86.040001
# 2    2020-03-18   77.800003   80.972000   70.101997   72.244003   72.244003
# 3    2020-03-19   74.940002   90.400002   71.692001   85.528000   85.528000
# 4    2020-03-20   87.639999   95.400002   85.157997   85.505997   85.505997
# ..          ...         ...         ...         ...         ...         ...
# 246  2021-03-08  600.549988  620.130005  558.789978  563.000000  563.000000
# 247  2021-03-09  608.179993  678.090027  595.210022  673.580017  673.580017
# 248  2021-03-10  700.299988  717.849976  655.059998  668.059998  668.059998
# 249  2021-03-11  699.400024  702.500000  677.179993  699.599976  699.599976
# 250  2021-03-12  670.000000  694.880005  666.140015  693.729980  693.729980
#
#         Volume
# 0    102447500
# 1    119973000
# ...

# %%
columns=['Date','Close']
ndf=pd.DataFrame(df, columns=columns)
ndf
# Out:
#            Date       Close
# 0    2020-03-16   89.014000
# 1    2020-03-17   86.040001
# 2    2020-03-18   72.244003
# 3    2020-03-19   85.528000
# 4    2020-03-20   85.505997
# ..          ...         ...
# 246  2021-03-08  563.000000
# 247  2021-03-09  673.580017
# 248  2021-03-10  668.059998
# 249  2021-03-11  699.599976
# 250  2021-03-12  693.729980
#
# [251 rows x 2 columns]

# %%
prophet_df=ndf.rename(columns={'Date':'ds', 'Close':'y'})
prophet_df
# Out:
#              ds           y
# 0    2020-03-16   89.014000
# 1    2020-03-17   86.040001
# 2    2020-03-18   72.244003
# 3    2020-03-19   85.528000
# 4    2020-03-20   85.505997
# ..          ...         ...
# 246  2021-03-08  563.000000
# 247  2021-03-09  673.580017
# 248  2021-03-10  668.059998
# 249  2021-03-11  699.599976
# 250  2021-03-12  693.729980
#
# [251 rows x 2 columns]

# %% [markdown]
# ## Creating Facebook Prophet Model

# %%
m=Prophet()
m.fit(prophet_df)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# ##Forecasting

# %%
future=m.make_future_dataframe(periods=30)
forecast=m.predict(future)
forecast
# Out:
#             ds       trend  yhat_lower   yhat_upper  trend_lower  trend_upper  \
# 0   2020-03-16   65.592384  -25.700270   146.012522    65.592384    65.592384
# 1   2020-03-17   67.387841  -21.708054   152.924153    67.387841    67.387841
# 2   2020-03-18   69.183298  -12.158474   146.400205    69.183298    69.183298
# 3   2020-03-19   70.978755  -18.729445   152.670562    70.978755    70.978755
# 4   2020-03-20   72.774212  -25.163544   147.689508    72.774212    72.774212
# ..         ...         ...         ...          ...          ...          ...
# 276 2021-04-07  900.261779  813.162345   986.872014   899.311046   901.369856
# 277 2021-04-08  902.718796  808.110084   978.906776   901.694306   903.925607
# 278 2021-04-09  905.175813  810.571348   975.723548   904.079570   906.453079
# 279 2021-04-10  907.632829  828.803087  1007.462902   906.462317   908.993051
# 280 2021-04-11  910.089846  831.129136  1009.721496   908.826344   911.531872
#
# ...

# %%
px.line(forecast, x='ds', y='yhat')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
figure=m.plot(forecast, xlabel='ds',ylabel='y')

# %%
figure2=m.plot_components(forecast)

# %% [markdown]
# ##Downloading the Forecast data

# %%
from google.colab import files
forecast.to_csv('TSLAforecast.csv')
files.download('TSLAforecast.csv')
